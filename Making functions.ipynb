# %%
import os.path
import pandas as pd

import re #regular expression matching for removing unwanted columns by name 
import natsort as ns #3rd party package for natural sorting

# %%
def raw_data_cleanup(filename):
    """
    Imports RNAseq .csv file and does basic clean up of "FM40" 
        -sorts FM40 timecourse sequence chronologically
        -removes all QC data and non FM40 columns
        -returns dataframe with locus tag set as index
    
    """

    if os.path.isfile(filename):
        print("{} was located in the directory".format(filename))
                
#import the data
        data0_raw = pd.read_csv(filename, sep = "\t") 
        print("{} was imported into dataframe".format(filename))
        
#removing all QC data
        data1_noQC = data0_raw.select(lambda x: not re.search("QC", x), axis = 1) 
        print("QC columns were removed from dataframe")

#removing all non FM40 data
        data2_FM40only = data1_noQC.select(lambda x: re.search("FM40", x), axis = 1)
        print("All non FM40 data were removed from dataframe")
        
#naturally sorting FM40 data by columns 
        cols = list(ns.natsorted(data2_FM40only.columns))
        data3_sorted=data2_FM40only[cols]
        print("All FM40 columns were sorted by timecourse sequence")
        
#adding the descriptor columns back to FM40
        qualitative = data0_raw.loc[:,"locus_tag":"translation"]
        data4_sorted = pd.concat([qualitative, data3_sorted], axis = 1)

#setting locus tag to be the index
        data5_index = data4_sorted.set_index("locus_tag")
        
    
        print("Clean-up of raw data complete")
        return data5_index
        
    else:
        print("{} does not exist in directory. Function was not complete.".format(filename))
        return

# %%
df1 = raw_data_cleanup("5G_counts.tsv")
# Out:
# 5G_counts.tsv was located in the directory
# 5G_counts.tsv was imported into dataframe
# QC columns were removed from dataframe
# All non FM40 data were removed from dataframe
# All FM40 columns were sorted by timecourse sequence
# Clean-up of raw data complete

# %% [markdown]
# ### Calculating TPM counts

# %%
columns = ['5GB1_FM40_T0m_TR2', '5GB1_FM40_T10m_TR3', '5GB1_FM40_T20m_TR2', '5GB1_FM40_T40m_TR1', 
           '5GB1_FM40_T60m_TR1', '5GB1_FM40_T90m_TR2', '5GB1_FM40_T150m_TR1_remake', '5GB1_FM40_T180m_TR1']

#df1.loc[]

# %%
def TPM_counts(dataframe, 
              gene_start,
              gene_stop,
              columns):
    
    """           
    TPM_counts(dataframe, gene_start, gene_stop, columns):
    
    Parameters
    ----------
    daraframe = dataframe object variable 
    gene_start = string with column name containing gene start coordinate 
    gene_stop = string with column name containing gene stop coordinate 
    columns = list of strings of column names to be converted to TPM
    """
    
    #create empty dataframe 
    gene_length = pd.DataFrame()
    
    #gene length in kilo base pairs as new column
    gene_length["gene_length"] = (dataframe[gene_stop]- dataframe[gene_start] + 1)/1000   
    
    #normalize read counts by gene length in kilo base pairs
    RPK = dataframe.loc[:,columns].div(gene_length.gene_length, axis=0) 
    
    #creating a series with the sums of each FM40 column / 1,000,000
    norm_sum = RPK.sum(axis=0)/1000000 
    norm_sum1 = pd.Series.to_frame(norm_sum)
    norm_sum2 = norm_sum1.T
    
    #dividing by the the total transcript counts in each repicate
    TPM = RPK.div(norm_sum2.ix[0]) 
    
    dataframe.loc[:,columns] = TPM
    
    return dataframe

# %%
df1 = TPM_counts(df1,"start_coord","end_coord",columns)

# %%
df1
# Out:
#                                                          product  type  \
# locus_tag
# MBURv2_100001              conserved protein of unknown function   CDS
# MBURv2_100002              conserved protein of unknown function   CDS
# MBURv2_100003                        protein of unknown function   CDS
# MBURv2_10001                         protein of unknown function   CDS
# MBURv2_10002                                                KfrB   CDS
# MBURv2_10003                                        Protein traN   CDS
# MBURv2_10004                                        Protein TraM   CDS
# MBURv2_10005                                        Protein TraL   CDS
# MBURv2_10006                                        Protein TraK   CDS
# MBURv2_10007                                        Protein TraJ   CDS
# MBURv2_10008                                        Protein TraI   CDS
# MBURv2_10009                      Conjugal transfer protein TraG   CDS
# MBURv2_10010                       Plasmid transfer protein TraF   CDS
# MBURv2_10011                                 DNA topoisomerase 3   CDS
# MBURv2_10012                                        TraD protein   CDS
# MBURv2_10013                  DNA primase traC (Modular protein)   CDS
# MBURv2_10014               conserved protein of unknown function   CDS
# MBURv2_10015   Glutathione-dependent formaldehyde-activating,...   CDS
# MBURv2_10016   putative antioxidant peroxiredoxin-related pro...   CDS
# MBURv2_10017               conserved protein of unknown function   CDS
# MBURv2_10018   Pyridoxamine 5'-phosphate oxidase-related FMN-...   CDS
# MBURv2_10019                         protein of unknown function   CDS
# MBURv2_10020                           Methyltransferase type 11   CDS
# MBURv2_10021      conserved membrane protein of unknown function   CDS
# MBURv2_10022                     Methyltransferase domain family   CDS
# MBURv2_10023                        Plasmid stabilization system   CDS
# MBURv2_10024               conserved protein of unknown function   CDS
# MBURv2_10025                                     Phage integrase   CDS
# MBURv2_10026                         protein of unknown function   CDS
# MBURv2_10027                        O-methyltransferase family 2   CDS
# ...                                                          ...   ...
# MBURv2_tRNA22                                           Ile tRNA  tRNA
# MBURv2_tRNA23                                           Ala tRNA  tRNA
# MBURv2_tRNA24                                           Arg tRNA  tRNA
# MBURv2_tRNA25                                           Ile tRNA  tRNA
# MBURv2_tRNA26                                           Ala tRNA  tRNA
# MBURv2_tRNA27                                           Gln tRNA  tRNA
# MBURv2_tRNA28                                           Tyr tRNA  tRNA
# MBURv2_tRNA29                                           Gly tRNA  tRNA
# MBURv2_tRNA3                                            Asp tRNA  tRNA
# MBURv2_tRNA30                                           Thr tRNA  tRNA
# MBURv2_tRNA31                                           Trp tRNA  tRNA
# MBURv2_tRNA32                                           Met tRNA  tRNA
# MBURv2_tRNA33                                           Ala tRNA  tRNA
# MBURv2_tRNA34                                           Glu tRNA  tRNA
# MBURv2_tRNA35                                           Glu tRNA  tRNA
# MBURv2_tRNA36                                           Val tRNA  tRNA
# MBURv2_tRNA37                                           Pro tRNA  tRNA
# MBURv2_tRNA38                                           Ser tRNA  tRNA
# MBURv2_tRNA39                                           Arg tRNA  tRNA
# MBURv2_tRNA4                                            Asp tRNA  tRNA
# MBURv2_tRNA40                                           Asn tRNA  tRNA
# MBURv2_tRNA41                                           Leu tRNA  tRNA
# MBURv2_tRNA42                                           Gly tRNA  tRNA
# MBURv2_tRNA43                                           Cys tRNA  tRNA
# MBURv2_tRNA44                                           Leu tRNA  tRNA
# MBURv2_tRNA5                                            Met tRNA  tRNA
# MBURv2_tRNA6                                            Ser tRNA  tRNA
# MBURv2_tRNA7                                            Leu tRNA  tRNA
# MBURv2_tRNA8                                            Ser tRNA  tRNA
# MBURv2_tRNA9                                            Thr tRNA  tRNA
#
#               gene_symbol   locus  start_coord  end_coord  \
# locus_tag
# MBURv2
evidence 4 : Homologs of previously reported g...          NaN
# MBURv2_100002  Evidence 4 : Homologs of previously reported g...          NaN
# MBURv2_100003  Evidence 5 : No homology to any previously rep...          NaN
# MBURv2_10001   Evidence 5 : No homology to any previously rep...          NaN
# MBURv2_10002                                                 NaN          NaN
# MBURv2_10003                                                 NaN          NaN
# MBURv2_10004                                                 NaN          NaN
# MBURv2_10005                                                 NaN          NaN
# MBURv2_10006                                                 NaN          NaN
# MBURv2_10007                                                 NaN          NaN
# MBURv2_10008                                                 NaN          NaN
# MBURv2_10009                                                 NaN          NaN
# MBURv2_10010                                                 NaN          NaN
# MBURv2_10011                                                 NaN          NaN
# MBURv2_10012                                                 NaN          NaN
# MBURv2_10013                                                 NaN          NaN
# MBURv2_10014   Evidence 4 : Homologs of previously reported g...          NaN
# MBURv2_10015                                                 NaN          NaN
# MBURv2_10016   Evidence 3 : Function proposed based on presen...          NaN
# MBURv2_10017   Evidence 4 : Homologs of previously reported g...          NaN
# MBURv2_10018                                                 NaN          NaN
# MBURv2_10019   Evidence 5 : No homology to any previously rep...          NaN
# MBURv2_10020                                                 NaN          NaN
# MBURv2_10021   Evidence 4 : Homologs of previously reported g...          NaN
# MBURv2_10022                                                 NaN          NaN
# MBURv2_10023                                                 NaN          NaN
# MBURv2_10024   Evidence 4 : Homologs of previously reported g...          NaN
# MBURv2_10025                                                 NaN          NaN
# MBURv2_10026   Evidence 5 : No homology to any previously rep...          NaN
# MBURv2_10027                                                 NaN          NaN
# ...                                                          ...          ...
# MBURv2_tRNA22                                                NaN          NaN
# MBURv2_tRNA23                                                NaN          NaN
# MBURv2_tRNA24                                                NaN          NaN
# MBURv2_tRNA25                                                NaN          NaN
# MBURv2_tRNA26                                                NaN          NaN
# MBURv2_tRNA27                                                NaN          NaN
# MBURv2_tRNA28                                                NaN          NaN
# MBURv2_tRNA29                                                NaN          NaN
# MBURv2_tRNA3                                                 NaN          NaN
# MBURv2_tRNA30                                                NaN          NaN
# MBURv2_tRNA31                                                NaN          NaN
# MBURv2_tRNA32                                                NaN          NaN
# MBURv2_tRNA33                                                NaN          NaN
# MBURv2_tRNA34                                                NaN          NaN
# MBURv2_tRNA35                                                NaN          NaN
# MBURv2_tRNA36                                                NaN          NaN
# MBURv2_tRNA37                                                NaN          NaN
# MBURv2_tRNA38                                                NaN          NaN
# MBURv2_tRNA39                                                NaN          NaN
# MBURv2_tRNA4                                                 NaN          NaN
# MBURv2_tRNA40                                                NaN          NaN
# MBURv2_tRNA41                                                NaN          NaN
# MBURv2_tRNA42                                                NaN          NaN
# MBURv2_tRNA43                                                NaN          NaN
# MBURv2_tRNA44                                                NaN          NaN
# MBURv2_tRNA5                                                 NaN          NaN
# MBURv2_tRNA6                                                 NaN          NaN
# MBURv2_tRNA7                                                 NaN          NaN
# MBURv2_tRNA8                                                 NaN          NaN
# MBURv2_tRNA9                                                 NaN          NaN
#
#                5GB1_FM40_T0m_TR2  5GB1_FM40_T10m_TR3
GB1_FM40_T180m_TR1
# locus_tag
# MBURv2_100001                   23.793199            21.197329
# MBURv2_100002                    4.915027             4.634447
# MBURv2_100003                    5.977735             0.939415
# MBURv2_10001                    11.058811             7.491024
# MBURv2_10002                    95.143906           105.923083
# MBURv2_10003                   111.386799            95.223404
# MBURv2_10004                    25.879122            21.871753
# MBURv2_10005                    22.635527            23.842506
# MBURv2_10006                    36.049981            41.600548
# MBURv2_10007                    18.401381            22.889647
# MBURv2_10008                    10.476239            10.181261
# MBURv2_10009                    14.931139            14.747629
# MBURv2_10010                     7.165447             6.736872
# MBURv2_10011                     4.530373             3.752895
# MBURv2_10012                     6.463597             2.856851
# MBURv2_10013                     5.502673             4.950706
# MBURv2_10014                    16.306752            15.838166
# MBURv2_10015                    17.461280            14.373755
# MBURv2_10016                    17.823307            19.170844
# MBURv2_10017                    26.343918            32.544445
# MBURv2_10018                    22.317962            31.074723
# MBURv2_10019                    16.532363            13.060714
# MBURv2_10020                    18.522146            24.827395
# MBURv2_10021                    24.709793            38.805558
# MBURv2_10022                    91.431841           115.618788
# MBURv2_10023                    52.059163            45.753342
# MBURv2_10024                    90.333875            90.524501
# MBURv2_10025                    21.273089            14.635096
# MBURv2_10026                    34.563738            27.470311
# MBURv2_10027                    17.156475            13.791518
# ...                                   ...                  ...
# MBURv2_tRNA22                    0.000000             0.000000
# MBURv2_tRNA23                    0.000000             0.000000
# MBURv2_tRNA24                   83.012890            73.805073
# MBURv2_tRNA25                    0.000000             0.000000
# MBURv2_tRNA26                    0.000000             0.000000
# MBURv2_tRNA27                 2180.502562          2255.817087
# MBURv2_tRNA28                 2458.178456          3457.024862
# MBURv2_tRNA29                 2128.671610          3637.649487
# MBURv2_tRNA3                  1362.962510           880.243996
# MBURv2_tRNA30                 3718.379577          4332.903065
# MBURv2_tRNA31                 1602.654483          2070.408716
# MBURv2_tRNA32                  242.432109           218.029667
# MBURv2_tRNA33                 2542.362369          4140.817432
# MBURv2_tRNA34                 1979.236088          2756.428834
# MBURv2_tRNA35                 1709.750334          2328.352280
# MBURv2_tRNA36                  596.026809           794.250928
# MBURv2_tRNA37                  386.053027           397.464020
# MBURv2_tRNA38                 1317.440923           944.709356
# MBURv2_tRNA39                 1447.411609          1281.093569
# MBURv2_tRNA4                    36.479713            21.667545
# MBURv2_tRNA40                  382.402032           514.515088
# MBURv2_tRNA41                  581.563338           594.981213
# MBURv2_tRNA42                  352.112532           294.750830
# MBURv2_tRNA43                   72.330600            95.115762
# MBURv2_tRNA44                   47.285949            53.935375
# MBURv2_tRNA5                   495.779408           515.281293
# MBURv2_tRNA6                   280.723655           514.500011
# MBURv2_tRNA7                   337.611507           333.200760
# MBURv2_tRNA8                   357.903327           466.275401
# MBURv2_tRNA9                     0.000000             0.000000
#
# [4593 rows x 16 columns]

# %%
type(df1)

# %%
strengths = TPM_counts(df1,"start_coord","end_coord",columns)

# %%
df_A = pd.DataFrame({"A": [1,2,3,4,5,6],
                    "B": [10,20,30,40,50,60]},
                   index = [1,1,1,2,2,2])

# %%
df_A

# %%
df_B = pd.DataFrame({"divide_by": [0.5,10]},
                    index = [1,2])

# %%
df_B

# %%
result = df_A.div(df_B, axis = 0)

# %%
result
