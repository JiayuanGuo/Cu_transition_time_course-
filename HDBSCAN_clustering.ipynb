# %%
import os.path
import pandas as pd
import numpy as np

import hdbscan
import time
from sklearn import metrics

from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances

import re #regular expression matching for removing unwanted columns by name 
import natsort as ns #3rd party package for natural sorting

# %%
def raw_data_cleanup(filename):
    
    """
    Imports RNAseq .csv file and does basic clean up of "FM40" 
        -sorts FM40 timecourse sequence chronologically
        -removes all QC data and non FM40 columns
        -returns dataframe with locus tag set as index
    """

    if os.path.isfile(filename):
        print("{} was located in the directory".format(filename))
                
#import the data
        data0_raw = pd.read_csv(filename, sep = "\t") 
        print("{} was imported into dataframe".format(filename))
        
#removing all QC data
        data1_noQC = data0_raw.select(lambda x: not re.search("QC", x), axis = 1) 
        print("QC columns were removed from dataframe")

#removing all non FM40 data
        data2_FM40only = data1_noQC.select(lambda x: re.search("FM40", x), axis = 1)
        print("All non FM40 data were removed from dataframe")
        
#naturally sorting FM40 data by columns 
        cols = list(ns.natsorted(data2_FM40only.columns))
        data3_sorted=data2_FM40only[cols]
        print("All FM40 columns were sorted by timecourse sequence")
        
#adding the descriptor columns back to FM40
        qualitative = data0_raw.loc[:,"locus_tag":"translation"]
        data4_sorted = pd.concat([qualitative, data3_sorted], axis = 1)

#setting locus tag to be the index
        data5_index = data4_sorted.set_index("locus_tag")
        
    
        print("Clean-up of raw data complete")
        return data5_index
        
    else:
        print("{} does not exist in directory. Function was not complete.".format(filename))
        return

# %%
def TPM_counts(dataframe, 
              gene_start,
              gene_stop,
              columns):
    
    """
    TPM_counts(dataframe, gene_start, gene_stop, columns):

    returns a dataframe with TPM instead of reads

    Parameters
    ----------
    daraframe = dataframe object variable
    gene_start = string with column name containing gene start coordinate
    gene_stop = string with column name containing gene stop coordinate
    columns = list of strings of column names to be converted to TPM


    Run the following two lines to properly execute this function:

    columns = ['5GB1_FM40_T0m_TR2', '5GB1_FM40_T10m_TR3', '5GB1_FM40_T20m_TR2', '5GB1_FM40_T40m_TR1',
           '5GB1_FM40_T60m_TR1', '5GB1_FM40_T90m_TR2', '5GB1_FM40_T150m_TR1_remake', '5GB1_FM40_T180m_TR1']

    TPM_counts(df,"start_coord","end_coord",columns)
    """
    
    #create empty dataframe 
    gene_length = pd.DataFrame()
    
    #gene length in kilo base pairs as new column
    gene_length["gene_length"] = (dataframe[gene_stop]- dataframe[gene_start] + 1)/1000   
    
    #normalize read counts by gene length in kilo base pairs
    RPK = dataframe.loc[:,columns].div(gene_length.gene_length, axis=0) 
    
    #creating a series with the sums of each FM40 column / 1,000,000
    norm_sum = RPK.sum(axis=0)/1000000 
    norm_sum1 = pd.Series.to_frame(norm_sum)
    norm_sum2 = norm_sum1.T
    
    #dividing by the the total transcript counts in each repicate
    TPM = RPK.div(norm_sum2.ix[0]) 
    
    dataframe.loc[:,columns] = TPM
    
    return dataframe

# %% [markdown]
# ### Log2 fold transfrom of the TPM data.

# %%
def log_2_transform(dataframe,
                    first_data_column,
                    last_data_column):
                  
    """
    log_2_transform(dataframe, 
                    first_data_column, 
                    last_data_column)
    
    Return a new dataframe with the range of data columns log2 transformed. 
    *all zero values are changed to 1 (yield 0 after transform)
    *all values less than 1 are changed to 1 (yield 0 after transform)
    
    Parameters
    ----------
    daraframe = dataframe object variable
    first_data_column = first column that contains actual data (first non categorical)
    last_data_column = last column taht contains actual data (last non categorigal column)

    Run the following to execute the function for Cu transition dataset. 

    log_2_transform(df, "5GB1_FM40_T0m_TR2", "5GB1_FM40_T180m_TR1") 
    
    """
    
    df_data = dataframe.loc[:,first_data_column:last_data_column] #isolate the data
    
    df_data = df_data.replace(0,1) #replace all zeros with 1s
    
    df_data[df_data<1] = 1 #replace all values less than 1 with 1
    
    df_data_log2 = df_data.apply(np.log2)
    
    return df_data_log2

# %% [markdown]
# ### Mean center the data

# %%
def mean_center(df, first_data_column, last_data_column):       
        
        
    """
    mean_center(dataframe, 
                first_data_column, 
                last_data_column)
    
    Return a new dataframe with the range of data columns log2 transformed. 
    
    Parameters
    ----------
    daraframe = dataframe object variable
    first_data_column = first column that contains actual data (first non categorical)
    last_data_column = last column taht contains actual data (last non categorigal column)

    Run the following to execute the function for Cu transition dataset. 

    mean_center(df, "5GB1_FM40_T0m_TR2", "5GB1_FM40_T180m_TR1") 
    
    """

    df2_TPM_values = df2_TPM.loc[:,first_data_column:last_data_column] #isolating the data values 
    df2_TPM_values_T = df2_TPM_values.T #transposing the data

    standard_scaler = StandardScaler(with_std=False)
    TPM_counts_mean_centered = standard_scaler.fit_transform(df2_TPM_values_T) #mean centering the data 

    TPM_counts_mean_centered = pd.DataFrame(TPM_counts_mean_centered) #back to Dataframe

    #transposing back to original form and reincerting indeces and columns 
    my_index = df2_TPM_values.index
    my_columns = df2_TPM_values.columns

    TPM_counts_mean_centered = TPM_counts_mean_centered.T
    TPM_counts_mean_centered.set_index(my_index, inplace=True)
    TPM_counts_mean_centered.columns = my_columns
    
    return TPM_counts_mean_centered

# %% [markdown]
# ### Pariwise distance metric table - euclidean distance

# %%
def euclidean_distance(dataframe, first_data_column, last_data_column):
    
    """
    euclidean_distance(dataframe, 
                first_data_column, 
                last_data_column)
    
    Return a new dataframe - pairwise distance metric table, euclidean distance between every pair of rows. 
    
    Parameters
    ----------
    daraframe = dataframe object variable
    first_data_column = first column that contains actual data (first non categorical)
    last_data_column = last column taht contains actual data (last non categorigal column)

    Run the following to execute the function for Cu transition dataset. 

    euclidean_distance(df, "5GB1_FM40_T0m_TR2", "5GB1_FM40_T180m_TR1") 
    
    """
    
    
    df_values = dataframe.loc[:,first_data_column:last_data_column] #isolating the data values 

    df_euclidean_distance = pd.DataFrame(euclidean_distances(df_values))

    my_index = dataframe.index
    
    df_euclidean_distance = df_euclidean_distance.set_index(my_index)
    df_euclidean_distance.columns = my_index
    
    return df_euclidean_distance

# %%
def congruency_table(df, 
         data_clm_strt, 
         data_clm_stop, 
         step, 
         mask_diagonal=False):
    
    """
    
    corr(df, data_clm_strt, data_clm_stop, step = len(df.columns), mask_diagonal=False)
    
    returns a new datafram - congruency table - a pairwise pearson correlation matrix for every row pair
    
    Parameters
    ----------
    
    df - dataframe argument - recommended to use TPM counts for RNAseq datasets. 
    data_clm_strt = first column that contains data to be processed 
    data_clm_stop = last column that contains data to be processed
    step = length of dataset 
    mask_diagonal = mask diagonal values which shoud come out as 1
    
    
    Run the following lines to execute the function for my data
    
    congruency_table(df1, "5GB1_FM40_T0m_TR2" , "5GB1_FM40_T180m_TR1")
    
    """
    
    df = df.loc[:, data_clm_strt: data_clm_stop] #isolating the rows that are relavent to us. 
    df = df.T 
    
    n = df.shape[0]

    def corr_closure(df):
        d = df.values
        sums = d.sum(0, keepdims=True)
        stds = d.std(0, keepdims=True)

        def corr_(k=0, l=10):
            d2 = d.T.dot(d[:, k:l])
            sums2 = sums.T.dot(sums[:, k:l])
            stds2 = stds.T.dot(stds[:, k:l])

            return pd.DataFrame((d2 - sums2 / n) / stds2 / n,
                                df.columns, df.columns[k:l])

        return corr_

    c = corr_closure(df)

    step = min(step, df.shape[1])

    tups = zip(range(0, n, step), range(step, n + step, step))

    corr_table = pd.concat([c(*t) for t in tups], axis=1)

    corr_table = corr_table.fillna(value = 0) #there are 94 NA values - filling them with zeros 
    
    if mask_diagonal:
        np.fill_diagonal(corr_table.values, np.nan)

    return corr_table

# %%
df1_raw_FM40 = raw_data_cleanup("5G_counts.tsv")


columns = ['5GB1_FM40_T0m_TR2', '5GB1_FM40_T10m_TR3', '5GB1_FM40_T20m_TR2', '5GB1_FM40_T40m_TR1',
           '5GB1_FM40_T60m_TR1', '5GB1_FM40_T90m_TR2', '5GB1_FM40_T150m_TR1_remake', '5GB1_FM40_T180m_TR1']

df2_TPM = TPM_counts(df1_raw_FM40, "start_coord", "end_coord",columns)  #TPM counts
df2_TPM_log2 = log_2_transform(df2_TPM, "5GB1_FM40_T0m_TR2","5GB1_FM40_T180m_TR1") #TPM log 2 transformed 
df2_TPM_mean = mean_center(df2_TPM, "5GB1_FM40_T0m_TR2","5GB1_FM40_T180m_TR1") #TPM mean centered 

df3_pearson_r = congruency_table(df2_TPM, "5GB1_FM40_T0m_TR2" , "5GB1_FM40_T180m_TR1", step = df2_TPM.shape[0])
df3_euclidean_mean = euclidean_distance(df2_TPM_mean, "5GB1_FM40_T0m_TR2" , "5GB1_FM40_T180m_TR1")
df3_euclidean_log2 = euclidean_distance(df2_TPM_mean, "5GB1_FM40_T0m_TR2" , "5GB1_FM40_T180m_TR1" )

print("The shape of the TPM table is ", df2_TPM.shape)
print("The shape of the pearson_r matrix is ", df3_pearson_r.shape)
# Out:
# 5G_counts.tsv was located in the directory
# 5G_counts.tsv was imported into dataframe
# QC columns were removed from dataframe
# All non FM40 data were removed from dataframe
# All FM40 columns were sorted by timecourse sequence
# Clean-up of raw data complete
# The shape of the TPM table is  (4593, 16)
# The shape of the pearson_r matrix is  (4593, 4593)

# %% [markdown]
#    ### Clustering pearsons_r with HDBSCAN

# %%
# Clustering the pearsons_R with N/A vlaues removed 

hdb_t1 = time.time()
hdb_pearson_r = hdbscan.HDBSCAN(metric = "precomputed", min_cluster_size=10).fit(df3_pearson_r)
hdb_pearson_r_labels = hdb_pearson_r.labels_
hdb_elapsed_time = time.time() - hdb_t1
print("time to cluster", hdb_elapsed_time)
# Out:
# time to cluster 2.9324939250946045

# %%
print(np.unique(hdb_pearson_r_labels)) # unique bins, zero is noise
print(np.bincount(hdb_pearson_r_labels[hdb_pearson_r_labels!=-1]))
# Out:
# [-1  0  1]
# [4532   60]

# %%
pearson_clusters = {i: np.where(hdb_pearson_r_labels == i)[0] for i in range(2)}

# %%
df2_TPM.iloc[pearson_clusters[1],:]
# Out:
#                                                              product  type  \
# locus_tag
# MBURv2_20054                   conserved protein of unknown function   CDS
# MBURv2_20174       fragment of bifunctional protein [Includes: pu...   CDS
# MBURv2_20175       fragment of bifunctional protein [Includes: pu...   CDS
# MBURv2_210020                            protein of unknown function   CDS
# MBURv2_210100                  conserved protein of unknown function   CDS
# MBURv2_210106                  conserved protein of unknown function   CDS
# MBURv2_210193                  conserved protein of unknown function   CDS
# MBURv2_210222      fragment of dTDP-4-dehydrorhamnose reductase s...   CDS
# MBURv2_210223      fragment of dTDP-4-dehydrorhamnose reductase s...   CDS
# MBURv2_210226                  conserved protein of unknown function   CDS
# MBURv2_210235                  conserved protein of unknown function   CDS
# MBURv2_210236                  conserved protein of unknown function   CDS
# MBURv2_210376                            protein of unknown function   CDS
# MBURv2_210378                            protein of unknown function   CDS
# MBURv2_210491                            protein of unknown function   CDS
# MBURv2_210492                            protein of unknown function   CDS
# MBURv2_210493                                 transposase (fragment)   CDS
# MBURv2_210539                                            transposase   CDS
# MBURv2_210585           Multicopper oxidase type 2 (Modular protein)   CDS
# MBURv2_210586                            protein of unknown function   CDS
# MBURv2_220001                  conserved protein of unknown function   CDS
# MBURv2_220006           Multicopper oxidase type 2 (Modular protein)   CDS
# MBURv2_23s_rRNA_1                             ribosomal RNA 23s_rRNA  rRNA
# MBURv2_23s_rRNA_3                             ribosomal RNA 23s_rRNA  rRNA
# MBURv2_240107                            protein of unknown function   CDS
# MBURv2_250001                  conserved protein of unknown function   CDS
# MBURv2_250123                            protein of unknown function   CDS
# MBURv2_260001                            protein of unknown function   CDS
# MBURv2_30001                             protein of unknown function   CDS
# MBURv2_30002            Adenine phosphoribosyltransferase (fragment)   CDS
# MBURv2_30003                             protein of unknown function   CDS
# MBURv2_30004                             protein of unknown function   CDS
# MBURv2_30005                             protein of unknown function   CDS
# MBURv2_30006                    exported protein of unknown function   CDS
# MBURv2_30007                             protein of unknown function   CDS
# MBURv2_30143                   conserved protein of unknown function   CDS
# MBURv2_5s_rRNA_1                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_5s_rRNA_2                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_5s_rRNA_3                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_60001                             protein of unknown function   CDS
# MBURv2_60002                   conserved protein of unknown function   CDS
# MBURv2_60054       RNA-directed DNA polymerase (Reverse transcrip...   CDS
# MBURv2_60098                                  transposase (fragment)   CDS
# MBURv2_60134                             protein of unknown function   CDS
# MBURv2_60137                             protein of unknown function   CDS
# MBURv2_60138                   conserved protein of unknown function   CDS
# MBURv2_60307                   conserved protein of unknown function   CDS
# MBURv2_60331                   conserved protein of unknown function   CDS
# MBURv2_60369                             protein of unknown function   CDS
# MBURv2_90005                             protein of unknown function   CDS
# MBURv2_tRNA12                                               Ile tRNA  tRNA
# MBURv2_tRNA13                                               Ala tRNA  tRNA
# MBURv2_tRNA14                                               Pro tRNA  tRNA
# MBURv2_tRNA15                                               Arg tRNA  tRNA
# MBURv2_tRNA16                                               His tRNA  tRNA
# MBURv2_tRNA20                                               Leu tRNA  tRNA
# MBURv2_tRNA22                                               Ile tRNA  tRNA
# MBURv2_tRNA23                                               Ala tRNA  tRNA
# MBURv2_tRNA25                                               Ile tRNA  tRNA
# MBURv2_tRNA26                                               Ala tRNA  tRNA
#
#                   gene_symbol   locus  start_coord  end_coord  \
# locus_tag
# MBURv2
# MBURv2_tRNA16             NaN  MBURv2      4327492    4327567
# MBURv2_tRNA20             NaN  MBURv2      3816074    3816160
# MBURv2_tRNA22             NaN  MBURv2      3349301    3349377
# MBURv2_tRNA23             NaN  MBURv2      3349154    3349229
# MBURv2_tRNA25             NaN  MBURv2      2890542    2890618
# MBURv2_tRNA26             NaN  MBURv2      2890395    2890470
#
#                                                                 note  \
# locus_tag
# MBURv2_20054       Evidence 4 : Homologs of previously reported g...
# MBURv2_20174       Evidence 2b : Function of strongly homologous ...
# MBURv2_20175       Evidence 2b : Function of strongly homologous ...
# MBURv2_210020      Evidence 5 : No homology to any previously rep...
# MBURv2_210100      Evidence 4 : Homologs of previously reported g...
# MBURv2_210106      Evidence 4 : Homologs of previously reported g...
# MBURv2_210193      Evidence 4 : Homologs of previously reported g...
# MBURv2_210222      Evidence 2a : Function of homologous gene expe...
# MBURv2_210223      Evidence 2a : Function of homologous gene expe...
# MBURv2_210226      Evidence 4 : Homologs of previously reported g...
# MBURv2_210235      Evidence 4 : Homologs of previously reported g...
# MBURv2_210236      Evidence 4 : Homologs of previously reported g...
# MBURv2_210376      Evidence 5 : No homology to any previously rep...
# MBURv2_210378      Evidence 5 : No homology to any previously rep...
# MBURv2_210491      Evidence 5 : No homology to any previously rep...
# MBURv2_210492      Evidence 5 : No homology to any previously rep...
# MBURv2_210493                                                    NaN
# MBURv2_210539                                                    NaN
# MBURv2_210585                                                    NaN
# MBURv2_210586      Evidence 5 : No homology to any previously rep...
# MBURv2_220001      Evidence 4 : Homologs of previously reported g...
# MBURv2_220006                                                    NaN
# MBURv2_23s_rRNA_1                                                NaN
# MBURv2_23s_rRNA_3                                                NaN
# MBURv2_240107      Evidence 5 : No homology to any previously rep...
# MBURv2_250001      Evidence 4 : Homologs of previously reported g...
# MBURv2_250123      Evidence 5 : No homology to any previously rep...
# MBURv2_260001      Evidence 5 : No homology to any previously rep...
# MBURv2_30001       Evidence 5 : No homology to any previously rep...
# MBURv2_30002                                                     NaN
# MBURv2_30003       Evidence 5 : No homology to any previously rep...
# MBURv2_30004       Evidence 5 : No homology to any previously rep...
# MBURv2_30005       Evidence 5 : No homology to any previously rep...
# MBURv2_30006       Evidence 5 : No homology to any previously rep...
# MBURv2_30007       Evidence 5 : No homology to any previously rep...
# MBURv2_30143       Evidence 4 : Homologs of previously reported g...
# MBURv2_5s_rRNA_1                                                 NaN
# MBURv2_5s_rRNA_2                                                 NaN
# MBURv2_5s_rRNA_3                                                 NaN
# MBURv2_60001       Evidence 5 : No homology to any previously rep...
# MBURv2_60002       Evidence 4 : Homologs of previously reported g...
# MBURv2_60054                                                     NaN
# MBURv2_60098                                                     NaN
# MBURv2_60134       Evidence 5 : No homology to any previously rep...
# MBURv2_60137       Evidence 5 : No homology to any previously rep...
# MBURv2_60138       Evidence 4 : Homologs of previously reported g...
# MBURv2_60307       Evidence 4 : Homologs of previously reported g...
# MBURv2_60331       Evidence 4 : Homologs of previously reported g...
# MBURv2_tRNA13                        0
# MBURv2_tRNA14                        0
# MBURv2_tRNA15                        0
# MBURv2_tRNA16                        0
# MBURv2_tRNA20                        0
# MBURv2_tRNA22                        0
# MBURv2_tRNA23                        0
# MBURv2_tRNA25                        0
# MBURv2_tRNA26                        0

# %% [markdown]
# Looks like there are two clusters, some expression and zero expression across samples.

# %% [markdown]
#    ### Clustering mean centered euclidean distance with with HDBSCAN

# %%
# Clustering the mean centered euclidean distance of TPM counts 

hdb_t1 = time.time()
hdb_euclidean_mean = hdbscan.HDBSCAN(metric = "precomputed", min_cluster_size=10).fit(df3_euclidean_mean)
hdb_euclidean_mean_labels = hdb_euclidean_mean.labels_
hdb_elapsed_time = time.time() - hdb_t1
print("time to cluster", hdb_elapsed_time)
# Out:
# time to cluster 2.549302101135254

# %%
print(np.unique(hdb_euclidean_mean_labels))
print(np.bincount(hdb_euclidean_mean_labels[hdb_euclidean_mean_labels!=-1]))
# Out:
# [-1  0  1]
# [26 67]

# %%
euclidean_mean_clusters = {i: np.where(hdb_euclidean_mean_labels == i)[0] for i in range(2)}
df2_TPM.iloc[euclidean_mean_clusters[1],:]
# Out:
#                                                              product  type  \
# locus_tag
# MBURv2_16s_rRNA_2                             ribosomal RNA 16s_rRNA  rRNA
# MBURv2_16s_rRNA_3                             ribosomal RNA 16s_rRNA  rRNA
# MBURv2_190002                                Fap1 adhesin (fragment)   CDS
# MBURv2_190028                            protein of unknown function   CDS
# MBURv2_190038                            protein of unknown function   CDS
# MBURv2_20037       fragment of bifunctional protein [Includes: ri...   CDS
# MBURv2_20040       fragment of bifunctional protein [Includes: ri...   CDS
# MBURv2_20054                   conserved protein of unknown function   CDS
# MBURv2_20174       fragment of bifunctional protein [Includes: pu...   CDS
# MBURv2_20175       fragment of bifunctional protein [Includes: pu...   CDS
# MBURv2_210020                            protein of unknown function   CDS
# MBURv2_210100                  conserved protein of unknown function   CDS
# MBURv2_210106                  conserved protein of unknown function   CDS
# MBURv2_210193                  conserved protein of unknown function   CDS
# MBURv2_210222      fragment of dTDP-4-dehydrorhamnose reductase s...   CDS
# MBURv2_210223      fragment of dTDP-4-dehydrorhamnose reductase s...   CDS
# MBURv2_210226                  conserved protein of unknown function   CDS
# MBURv2_210235                  conserved protein of unknown function   CDS
# MBURv2_210236                  conserved protein of unknown function   CDS
# MBURv2_210376                            protein of unknown function   CDS
# MBURv2_210378                            protein of unknown function   CDS
# MBURv2_210491                            protein of unknown function   CDS
# MBURv2_210492                            protein of unknown function   CDS
# MBURv2_210493                                 transposase (fragment)   CDS
# MBURv2_210539                                            transposase   CDS
# MBURv2_210585           Multicopper oxidase type 2 (Modular protein)   CDS
# MBURv2_210586                            protein of unknown function   CDS
# MBURv2_220001                  conserved protein of unknown function   CDS
# MBURv2_220006           Multicopper oxidase type 2 (Modular protein)   CDS
# MBURv2_23s_rRNA_1                             ribosomal RNA 23s_rRNA  rRNA
# ...                                                              ...   ...
# MBURv2_30003                             protein of unknown function   CDS
# MBURv2_30004                             protein of unknown function   CDS
# MBURv2_30005                             protein of unknown function   CDS
# MBURv2_30006                    exported protein of unknown function   CDS
# MBURv2_30007                             protein of unknown function   CDS
# MBURv2_30143                   conserved protein of unknown function   CDS
# MBURv2_5s_rRNA_1                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_5s_rRNA_2                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_5s_rRNA_3                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_60001                             protein of unknown function   CDS
# MBURv2_60002                   conserved protein of unknown function   CDS
# MBURv2_60054       RNA-directed DNA polymerase (Reverse transcrip...   CDS
# MBURv2_60098                                  transposase (fragment)   CDS
# MBURv2_60134                             protein of unknown function   CDS
# MBURv2_60137                             protein of unknown function   CDS
# MBURv2_60138                   conserved protein of unknown function   CDS
# MBURv2_60307                   conserved protein of unknown function   CDS
# MBURv2_60331                   conserved protein of unknown function   CDS
# MBURv2_60369                             protein of unknown function   CDS
# MBURv2_90005                             protein of unknown function   CDS
# MBURv2_tRNA12                                               Ile tRNA  tRNA
# MBURv2_tRNA13                                               Ala tRNA  tRNA
# MBURv2_tRNA14                                               Pro tRNA  tRNA
# MBURv2_tRNA15                                               Arg tRNA  tRNA
# MBURv2_tRNA16                                               His tRNA  tRNA
# MBURv2_tRNA20                                               Leu tRNA  tRNA
# MBURv2_tRNA22                                               Ile tRNA  tRNA
# MBURv2_tRNA23                                               Ala tRNA  tRNA
# MBURv2_tRNA25                                               Ile tRNA  tRNA
# MBURv2_tRNA26                                               Ala tRNA  tRNA
#
#                   gene_symbol   locus  start_coord  end_coord  \
# locus_tag
# MBURv2_16s_rRNA_2         NaN  MBURv2      3349450    3350972
# MBURv2_16s_rRNA_3         NaN  MBURv2      2890691    2892213
# MBURv2_190002             NaN  MBURv2      3939333    3942758
# MBURv2_190028             NaN  MBURv2      3972750    3972920
# MBURv2_190038             NaN  MBURv2      3978954    3979127
# MBURv2_20037        rnhA-dnaQ  MBURv2       126207     126650
# MBURv2_20040        rnhA-dnaQ  MBURv2       130762     131481
# MBURv2_20054              NaN  MBURv2       148660     149958
# MBURv2_20174              NaN  MBURv2       276069     276944
# MBURv2_20175              NaN  MBURv2       276946     278265
# MBURv2_210020             NaN  MBURv2      4117369    4117431
# MBURv2_210100             NaN  MBURv2      4207166    4207459
# MBURv2_210106             NaN  MBURv2      4215558    4216046
# MBURv2_210193             NaN  MBURv2      4320868    4321203
# MBURv2_210222            rmlD  MBURv2      4355214    4355459
# MBURv2_210223            rmlD  MBURv2      4355477    4356100
# MBURv2_210226             NaN  MBURv2      4357559    4357930
# MBURv2_210235             NaN  MBURv2      4364445    4365461
# MBURv2_210236             NaN  MBURv2      4365479    4365814
# MBURv2_210376             NaN  MBURv2      4509201    4509524
# MBURv2_210378             NaN  MBURv2      4510201    4510326
# MBURv2_210491             NaN  MBURv2      4612102    4612251
# MBURv2_210492             NaN  MBURv2      4612277    4612558
# MBURv2_210493             NaN  MBURv2      4612555    4613382
# MBURv2_210539             tnp  MBURv2      4655507    4656832
# MBURv2_210585             NaN  MBURv2      4711770    4712486
# MBURv2_210586             NaN  MBURv2      4712483    4712593
# MBURv2_220001             NaN  MBURv2      4712720    4713214
# MBURv2_220006             NaN  MBURv2      4722441    4723157
# MBURv2_23s_rRNA_1         NaN  MBURv2      4259195    4262088
# ...                       ...     ...          ...        ...
# MBURv2_30003              NaN  MBURv2       610881     611087
# MBURv2_30004              NaN  MBURv2       611287     611481
# MBURv2_30005              NaN  MBURv2       611705     611938
# MBURv2_30006              NaN  MBURv2       611908     612114
# MBURv2_30007              NaN  MBURv2       612121     612225
# MBURv2_30143              NaN  MBURv2       779061     779348
# MBURv2_5s_rRNA_1          NaN  MBURv2      4262382    4262496
# MBURv2_5s_rRNA_2          NaN  MBURv2      3345533    3345647
# MBURv2_5s_rRNA_3          NaN  MBURv2      2886774    2886888
# MBURv2_60001              NaN  MBURv2      1353445    1353657
# MBURv2_60002              NaN  MBURv2      1353594    1353881
# MBURv2_60054              NaN  MBURv2      1423080    1423385
# MBURv2_60098              NaN  MBURv2      1478123    1479139
# MBURv2_60134              NaN  MBURv2      1514452    1514634
# MBURv2_60137              NaN  MBURv2      1517603    1517758
# MBURv2_60138              NaN  MBURv2      1517768    1517944
# MBURv2_60307              NaN  MBURv2      1703652    1703945
# MBURv2_60331              NaN  MBURv2      1727783    1728271
# MBURv2_60369              NaN  MBURv2      1767488    1767631
# MBURv2_90005              NaN  MBURv2      1964951    1965037
# MBURv2_tRNA12             NaN  MBURv2      4258653    4258729
# MBURv2_tRNA13             NaN  MBURv2      4258801    4258876
# MBURv2_tRNA14             NaN  MBURv2      4327309    4327385
# MBURv2_tRNA15             NaN  MBURv2      4327390    4327466
# MBURv2_tRNA16             NaN  MBURv2      4327492    4327567
# MBURv2_tRNA20             NaN  MBURv2      3816074    3816160
# MBURv2_tRNA22             NaN  MBURv2      3349301    3349377
# MBURv2_tRNA23             NaN  MBURv2      3349154    3349229
# MBURv2_tRNA25             NaN  MBURv2      2890542    2890618
# MBURv2_tRNA26             NaN  MBURv2      2890395    2890470
#
#                                                                 note  \
# locus_tag
# MBURv2_16s_rRNA_2                                                NaN
# MBURv2_16s_rRNA_3                                                NaN
# MBURv2_190002                                                    NaN
# MBURv2_190028      Evidence 5 : No homology to any previously rep...
# MBURv2_190038      Evidence 5 : No homology to any previously rep...
# MBURv2_20037       Evidence 2a : Function of homologous gene expe...
# MBURv2_20040       Evidence 2a : Function of homologous gene expe...
# MBURv2_20054       Evidence 4 : Homologs of previously reported g...
# MBURv2_20174       Evidence 2b : Function of strongly homologous ...
# MBURv2_20175       Evidence 2b : Function of strongly homologous ...
# MBURv2_210020      Evidence 5 : No homology to any previously rep...
# MBURv2_210100      Evidence 4 : Homologs of previously reported g...
# MBURv2_210106      Evidence 4 : Homologs of previously reported g...
# MBURv2_210193      Evidence 4 : Homologs of previously reported g...
# MBURv2_210222      Evidence 2a : Function of homologous gene expe...
# MBURv2_210223      Evidence 2a : Function of homologous gene expe...
# MBURv2_210226      Evidence 4 : Homologs of previously reported g...
# MBURv2_210235      Evidence 4 : Homologs of previously reported g...
# MBURv2_210236      Evidence 4 : Homologs of previously reported g...
# MBURv2_210376      Evidence 5 : No homology to any previously rep...
# MBURv2_210378      Evidence 5 : No homology to any previously rep...
# MBURv2_210491      Evidence 5 : No homology to any previously rep...
# MBURv2_210492      Evidence 5 : No homology to any previously rep...
# MBURv2_210493                                                    NaN
# MBURv2_210539                                                    NaN
# MBURv2_210585                                                    NaN
# MBURv2_210586      Evidence 5 : No homology to any previously rep...
# MBURv2_220001      Evidence 4 : Homologs of previously reported g...
# MBURv2_220006                                                    NaN
# MBURv2_23s_rRNA_1                                                NaN
# ...                                                              ...
GB1_FM40_T180m_TR1
# locus_tag
# MBURv2_16s_rRNA_2                    0
# MBURv2_16s_rRNA_3                    0
# MBURv2_190002                        0
# MBURv2_190028                        0
# MBURv2_190038                        0
# MBURv2_20037                         0
# MBURv2_20040                         0
# MBURv2_20054                         0
# MBURv2_20174                         0
# MBURv2_20175                         0
# MBURv2_210020                        0
# MBURv2_210100                        0
# MBURv2_210106                        0
# MBURv2_210193                        0
# MBURv2_210222                        0
# MBURv2_210223                        0
# MBURv2_210226                        0
# MBURv2_210235                        0
# MBURv2_210236                        0
# MBURv2_210376                        0
# MBURv2_210378                        0
# MBURv2_210491                        0
# MBURv2_210492                        0
# MBURv2_210493                        0
# MBURv2_210539                        0
# MBURv2_210585                        0
# MBURv2_210586                        0
# MBURv2_220001                        0
# MBURv2_220006                        0
# MBURv2_23s_rRNA_1                    0
# ...                                ...
# MBURv2_30003                         0
# MBURv2_30004                         0
# MBURv2_30005                         0
# MBURv2_30006                         0
# MBURv2_30007                         0
# MBURv2_30143                         0
# MBURv2_5s_rRNA_1                     0
# MBURv2_5s_rRNA_2                     0
# MBURv2_5s_rRNA_3                     0
# MBURv2_60001                         0
# MBURv2_60002                         0
# MBURv2_60054                         0
# MBURv2_60098                         0
# MBURv2_60134                         0
# MBURv2_60137                         0
# MBURv2_60138                         0
# MBURv2_60307                         0
# MBURv2_60331                         0
# MBURv2_60369                         0
# MBURv2_90005                         0
# MBURv2_tRNA12                        0
# MBURv2_tRNA13                        0
# MBURv2_tRNA14                        0
# MBURv2_tRNA15                        0
# MBURv2_tRNA16                        0
# MBURv2_tRNA20                        0
# MBURv2_tRNA22                        0
# MBURv2_tRNA23                        0
# MBURv2_tRNA25                        0
# MBURv2_tRNA26                        0
#
# [67 rows x 16 columns]

# %% [markdown]
# Looks like 2 clusters - both with zero expression.

# %% [markdown]
# looks like wether it is a numpy array or pandas dataframe, the result is the same. lets now try to get index of the clustered points.

# %% [markdown]
#    ### Clustering log transformed euclidean distance with with HDBSCAN

# %%
# Clustering the log2 transformed euclidean distance of TPM counts 

hdb_t1 = time.time()
hdb_euclidean_log2 = hdbscan.HDBSCAN(metric = "precomputed", min_cluster_size=10).fit(df3_euclidean_log2)
hdb_euclidean_log2_labels = hdb_euclidean_log2.labels_
hdb_elapsed_time = time.time() - hdb_t1
print("time to cluster", hdb_elapsed_time)
# Out:
# time to cluster 3.291189193725586

# %%
print(np.unique(hdb_euclidean_log2_labels))
print(np.bincount(hdb_euclidean_log2_labels[hdb_euclidean_log2_labels!=-1]))
# Out:
# [-1  0  1]
# [26 67]

# %%
euclidean_log2_clusters = {i: np.where(hdb_euclidean_log2_labels == i)[0] for i in range(2)}
df2_TPM.iloc[euclidean_log2_clusters[1],:]
# Out:
#                                                              product  type  \
# locus_tag
# MBURv2_16s_rRNA_2                             ribosomal RNA 16s_rRNA  rRNA
# MBURv2_16s_rRNA_3                             ribosomal RNA 16s_rRNA  rRNA
# MBURv2_190002                                Fap1 adhesin (fragment)   CDS
# MBURv2_190028                            protein of unknown function   CDS
# MBURv2_190038                            protein of unknown function   CDS
# MBURv2_20037       fragment of bifunctional protein [Includes: ri...   CDS
# MBURv2_20040       fragment of bifunctional protein [Includes: ri...   CDS
# MBURv2_20054                   conserved protein of unknown function   CDS
# MBURv2_20174       fragment of bifunctional protein [Includes: pu...   CDS
# MBURv2_20175       fragment of bifunctional protein [Includes: pu...   CDS
# MBURv2_210020                            protein of unknown function   CDS
# MBURv2_210100                  conserved protein of unknown function   CDS
# MBURv2_210106                  conserved protein of unknown function   CDS
# MBURv2_210193                  conserved protein of unknown function   CDS
# MBURv2_210222      fragment of dTDP-4-dehydrorhamnose reductase s...   CDS
# MBURv2_210223      fragment of dTDP-4-dehydrorhamnose reductase s...   CDS
# MBURv2_210226                  conserved protein of unknown function   CDS
# MBURv2_210235                  conserved protein of unknown function   CDS
# MBURv2_210236                  conserved protein of unknown function   CDS
# MBURv2_210376                            protein of unknown function   CDS
# MBURv2_210378                            protein of unknown function   CDS
# MBURv2_210491                            protein of unknown function   CDS
# MBURv2_210492                            protein of unknown function   CDS
# MBURv2_210493                                 transposase (fragment)   CDS
# MBURv2_210539                                            transposase   CDS
# MBURv2_210585           Multicopper oxidase type 2 (Modular protein)   CDS
# MBURv2_210586                            protein of unknown function   CDS
# MBURv2_220001                  conserved protein of unknown function   CDS
# MBURv2_220006           Multicopper oxidase type 2 (Modular protein)   CDS
# MBURv2_23s_rRNA_1                             ribosomal RNA 23s_rRNA  rRNA
# ...                                                              ...   ...
# MBURv2_30003                             protein of unknown function   CDS
# MBURv2_30004                             protein of unknown function   CDS
# MBURv2_30005                             protein of unknown function   CDS
# MBURv2_30006                    exported protein of unknown function   CDS
# MBURv2_30007                             protein of unknown function   CDS
# MBURv2_30143                   conserved protein of unknown function   CDS
# MBURv2_5s_rRNA_1                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_5s_rRNA_2                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_5s_rRNA_3                               ribosomal RNA 5s_rRNA  rRNA
# MBURv2_60001                             protein of unknown function   CDS
# MBURv2_60002                   conserved protein of unknown function   CDS
# MBURv2_60054       RNA-directed DNA polymerase (Reverse transcrip...   CDS
# MBURv2_60098                                  transposase (fragment)   CDS
# MBURv2_60134                             protein of unknown function   CDS
# MBURv2_60137                             protein of unknown function   CDS
# MBURv2_60138                   conserved protein of unknown function   CDS
# MBURv2_60307                   conserved protein of unknown function   CDS
# MBURv2_60331                   conserved protein of unknown function   CDS
# MBURv2_60369                             protein of unknown function   CDS
# MBURv2_90005                             protein of unknown function   CDS
# MBURv2_tRNA12                                               Ile tRNA  tRNA
# MBURv2_tRNA13                                               Ala tRNA  tRNA
# MBURv2_tRNA14                                               Pro tRNA  tRNA
# MBURv2_tRNA15                                               Arg tRNA  tRNA
# MBURv2_tRNA16                                               His tRNA  tRNA
# MBURv2_tRNA20                                               Leu tRNA  tRNA
# MBURv2_tRNA22                                               Ile tRNA  tRNA
# MBURv2_tRNA23                                               Ala tRNA  tRNA
# MBURv2_tRNA25                                               Ile tRNA  tRNA
# MBURv2_tRNA26                                               Ala tRNA  tRNA
#
#                   gene_symbol   locus  start_coord  end_coord  \
# locus_tag
# MBURv2_16s_rRNA_2         NaN  MBURv2      3349450    3350972
# MBURv2_16s_rRNA_3         NaN  MBURv2      2890691    2892213
# MBURv2_190002             NaN  MBURv2      3939333    3942758
# MBURv2_190028             NaN  MBURv2      3972750    3972920
# MBURv2_190038             NaN  MBURv2      3978954    3979127
# MBURv2_20037        rnhA-dnaQ  MBURv2       126207     126650
# MBURv2_20040        rnhA-dnaQ  MBURv2       130762     131481
# MBURv2_20054              NaN  MBURv2       148660     149958
# MBURv2_20174              NaN  MBURv2       276069     276944
# MBURv2_20175              NaN  MBURv2       276946     278265
# MBURv2_210020             NaN  MBURv2      4117369    4117431
# MBURv2_210100             NaN  MBURv2      4207166    4207459
# MBURv2_210106             NaN  MBURv2      4215558    4216046
# MBURv2_210193             NaN  MBURv2      4320868    4321203
# MBURv2_210222            rmlD  MBURv2      4355214    4355459
# MBURv2_210223            rmlD  MBURv2      4355477    4356100
# MBURv2_210226             NaN  MBURv2      4357559    4357930
# MBURv2_210235             NaN  MBURv2      4364445    4365461
# MBURv2_210236             NaN  MBURv2      4365479    4365814
# MBURv2_210376             NaN  MBURv2      4509201    4509524
# MBURv2_210378             NaN  MBURv2      4510201    4510326
# MBURv2_210491             NaN  MBURv2      4612102    4612251
# MBURv2_210492             NaN  MBURv2      4612277    4612558
# MBURv2_210493             NaN  MBURv2      4612555    4613382
# MBURv2_210539             tnp  MBURv2      4655507    4656832
# MBURv2_210585             NaN  MBURv2      4711770    4712486
# MBURv2_210586             NaN  MBURv2      4712483    4712593
# MBURv2_220001             NaN  MBURv2      4712720    4713214
# MBURv2_220006             NaN  MBURv2      4722441    4723157
# MBURv2_23s_rRNA_1         NaN  MBURv2      4259195    4262088
# ...                       ...     ...          ...        ...
# MBURv2_30003              NaN  MBURv2       610881     611087
# MBURv2_30004              NaN  MBURv2       611287     611481
# MBURv2_30005              NaN  MBURv2       611705     611938
# MBURv2_30006              NaN  MBURv2       611908     612114
# MBURv2_30007              NaN  MBURv2       612121     612225
# MBURv2_30143              NaN  MBURv2       779061     779348
# MBURv2_5s_rRNA_1          NaN  MBURv2      4262382    4262496
# MBURv2_5s_rRNA_2          NaN  MBURv2      3345533    3345647
# MBURv2_5s_rRNA_3          NaN  MBURv2      2886774    2886888
# MBURv2_60001              NaN  MBURv2      1353445    1353657
# MBURv2_60002              NaN  MBURv2      1353594    1353881
# MBURv2_60054              NaN  MBURv2      1423080    1423385
# MBURv2_60098              NaN  MBURv2      1478123    1479139
# MBURv2_60134              NaN  MBURv2      1514452    1514634
# MBURv2_60137              NaN  MBURv2      1517603    1517758
# MBURv2_60138              NaN  MBURv2      1517768    1517944
# MBURv2_60307              NaN  MBURv2      1703652    1703945
# MBURv2_60331              NaN  MBURv2      1727783    1728271
# MBURv2_60369              NaN  MBURv2      1767488    1767631
# MBURv2_90005              NaN  MBURv2      1964951    1965037
# MBURv2_tRNA12             NaN  MBURv2      4258653    4258729
# MBURv2_tRNA13             NaN  MBURv2      4258801    4258876
# MBURv2_tRNA14             NaN  MBURv2      4327309    4327385
# MBURv2_tRNA15             NaN  MBURv2      4327390    4327466
# MBURv2_tRNA16             NaN  MBURv2      4327492    4327567
# MBURv2_tRNA20             NaN  MBURv2      3816074    3816160
# MBURv2_tRNA22             NaN  MBURv2      3349301    3349377
# MBURv2_tRNA23             NaN  MBURv2      3349154    3349229
# MBURv2_tRNA25             NaN  MBURv2      2890542    2890618
# MBURv2_tRNA26             NaN  MBURv2      2890395    2890470
#
#                                                                 note  \
# locus_tag
# MBURv2_16s_rRNA_2                                                NaN
# MBURv2_16s_rRNA_3                                                NaN
# MBURv2_190002                                                    NaN
# MBURv2_190028      Evidence 5 : No homology to any previously rep...
# MBURv2_190038      Evidence 5 : No homology to any previously rep...
# MBURv2_20037       Evidence 2a : Function of homologous gene expe...
# MBURv2_20040       Evidence 2a : Function of homologous gene expe...
# MBURv2_20054       Evidence 4 : Homologs of previously reported g...
# MBURv2_20174       Evidence 2b : Function of strongly homologous ...
# MBURv2_20175       Evidence 2b : Function of strongly homologous ...
# MBURv2_210020      Evidence 5 : No homology to any previously rep...
# MBURv2_210100      Evidence 4 : Homologs of previously reported g...
# MBURv2_210106      Evidence 4 : Homologs of previously reported g...
# MBURv2_210193      Evidence 4 : Homologs of previously reported g...
# MBURv2_210222      Evidence 2a : Function of homologous gene expe...
# MBURv2_210223      Evidence 2a : Function of homologous gene expe...
# MBURv2_210226      Evidence 4 : Homologs of previously reported g...
# MBURv2_210235      Evidence 4 : Homologs of previously reported g...
# MBURv2_210236      Evidence 4 : Homologs of previously reported g...
# MBURv2_210376      Evidence 5 : No homology to any previously rep...
# MBURv2_210378      Evidence 5 : No homology to any previously rep...
# MBURv2_210491      Evidence 5 : No homology to any previously rep...
# MBURv2_210492      Evidence 5 : No homology to any previously rep...
# MBURv2_210493                                                    NaN
# MBURv2_210539                                                    NaN
# MBURv2_210585                                                    NaN
# MBURv2_210586      Evidence 5 : No homology to any previously rep...
# MBURv2_220001      Evidence 4 : Homologs of previously reported g...
# MBURv2_220006                                                    NaN
# MBURv2_23s_rRNA_1                                                NaN
# ...                                                              ...
# MBURv2_30003       Evidence 5 : No homology to any previously rep...
# MBURv2_30004       Evidence 5 : No homology to any previously rep...
# MBURv2_30005       Evidence 5 : No homology to any previously rep...
# MBURv2_30006       Evidence 5 : No homology to any previously rep...
# MBURv2_30007       Evidence 5 : No homology to any previously rep...
# MBURv2_30143       Evidence 4 : Homologs of previously reported g...
# MBURv2_5s_rRNA_1                                                 NaN
# MBURv2_5s_rRNA_2                                                 NaN
# MBURv2_5s_rRNA_3                                                 NaN
# MBURv2_60001       Evidence 5 : No homology to any previously rep...
# MBURv2_60002       Evidence 4 : Homologs of previously reported g...
# MBURv2_60054                                                     NaN
# MBURv2_60098                                                     NaN
# MBURv2_60134       Evidence 5 : No homology to any previously rep...
# MBURv2_60137       Evidence 5 : No homology to any previously rep...
# MBURv2_60138       Evidence 4 : Homologs of previously reported g...
# MBURv2_60307       Evidence 4 : Homologs of previously reported g...
# MBURv2_60331       Evidence 4 : Homologs of previously reported g...
# MBURv2_60369       Evidence 5 : No homology to any previously rep...
# MBURv2_90005       Evidence 5 : No homology to any previously rep...
# MBURv2_tRNA12                                                    NaN
# MBURv2_tRNA13                                                    NaN
# MBURv2_tRNA14                                                    NaN
# MBURv2_tRNA15                                                    NaN
# MBURv2_tRNA16                                                    NaN
# MBURv2_tRNA20                                                    NaN
# MBURv2_tRNA22                                                    NaN
# MBURv2_tRNA23                                                    NaN
# MBURv2_tRNA25                                                    NaN
# MBURv2_tRNA26                                                    NaN
#
#                    translation  5GB1_FM40_T0m_TR2  5GB1_FM40_T10m_TR3